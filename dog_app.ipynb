# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this IPython notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Use a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 6](#step6): Write your Algorithm
# * [Step 7](#step7): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# ### Import Dog Dataset
#
# In the code cell below, we import a dataset of dog images.  We populate a few variables through the use of the `load_files` function from the scikit-learn library:
# - `train_files`, `valid_files`, `test_files` - numpy arrays containing file paths to images
# - `train_targets`, `valid_targets`, `test_targets` - numpy arrays containing onehot-encoded classification labels
# - `dog_names` - list of string-valued dog breed names for translating labels

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('/data/dog_images/train')
valid_files, valid_targets = load_dataset('/data/dog_images/valid')
test_files, test_targets = load_dataset('/data/dog_images/test')

# load list of dog names
dog_names = [item[20:-1] for item in sorted(glob("/data/dog_images/train/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# Using TensorFlow backend.
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### Import Human Dataset
#
# In the code cell below, we import a dataset of human images, where the file paths are stored in the numpy array `human_files`.

# %%
import random
random.seed(8675309)

# load filenames in shuffled human dataset
human_files = np.array(glob("/data/lfw/*/*"))
random.shuffle(human_files)

# print statistics about the dataset
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13233 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# We use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.  OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.
#
# In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline
import os
os.listdir("haarcascades")
# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')
profile_face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_profileface.xml')

print(os.listdir("haarcascades"))
# load color (BGR) image
img = cv2.imread(human_files[3])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# ['haarcascade_frontalface_alt.xml', 'haarcascade_profileface.xml']
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.
#
# __Answer:__

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
# Do NOT modify the code above this line.

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.

human_result = []
for x in human_files_short:
    human_result.append(face_detector(x))
dog_result = []
for x in dog_files_short:
    dog_result.append(face_detector(x))
    
print(sum(human_result))
print(sum(human_result) == len(human_files_short))
print(sum(dog_result))
print(sum(dog_result) == len(dog_files_short))
# Out:
# 100
# True
# 11
# False

# %% [markdown]
# __Question 2:__ This algorithmic choice necessitates that we communicate to the user that we accept human images only when they provide a clear view of a face (otherwise, we risk having unneccessarily frustrated users!). In your opinion, is this a reasonable expectation to pose on the user? If not, can you think of a way to detect humans in images that does not necessitate an image with a clearly presented face?
#
# __Answer:__
#
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on each of the datasets.
#
# __Student's Answer:__
# No, it is not a reasonable expectation since the domain of the application may require the detection of the face in real time. An example, is the detection of human faces in buildings and streets for secutiry purposes. I've added the profile face detector to the face detection algorithm. The addition of the profile face detector increased the number of detected faces by 40 images.

# %%
## (Optional) TODO: Report the performance of another  
## face detection algorithm on the LFW dataset
### Feel free to use as many code cells as needed.

#Will add an additional detector the profile face detector from opencv
def face_detector_extended(img_path):
	img = cv2.imread(img_path)
	gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
	faces = face_cascade.detectMultiScale(gray)
	side_face = profile_face_cascade.detectMultiScale(gray)
	return ( len(faces) > 0 or len(side_face) > 0)

human_result_extended = []
human_result_original = []
print("Total count of human files: " + str(len(human_files)))
for x in human_files:
	human_result_original.append(face_detector(x))
	human_result_extended.append(face_detector_extended(x))
print("Total faces detected with original detecter: " + str(sum(human_result_original)))
print("Total faces detected with extended detecter: " + str(sum(human_result_extended)))
# Out:
# Total count of human files: 13233
# Total faces detected with original detecter: 13067
# Total faces detected with extended detecter: 13107

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a pre-trained [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) model to detect dogs in images.  Our first line of code downloads the ResNet-50 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).  Given an image, this pre-trained ResNet-50 model returns a prediction (derived from the available categories in ImageNet) for the object that is contained in the image.

# %%
from keras.applications.resnet50 import ResNet50

# define ResNet50 model
ResNet50_model = ResNet50(weights='imagenet')
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102858752/102853048 [==============================] - 2s 0us/step

# %% [markdown]
# ### Pre-process the Data
#
# When using TensorFlow as backend, Keras CNNs require a 4D array (which we'll also refer to as a 4D tensor) as input, with shape
#
# $$
# (\text{nb_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# where `nb_samples` corresponds to the total number of images (or samples), and `rows`, `columns`, and `channels` correspond to the number of rows, columns, and channels for each image, respectively.
#
# The `path_to_tensor` function below takes a string-valued file path to a color image as input and returns a 4D tensor suitable for supplying to a Keras CNN.  The function first loads the image and resizes it to a square image that is $224 \times 224$ pixels.  Next, the image is converted to an array, which is then resized to a 4D tensor.  In this case, since we are working with color images, each image has three channels.  Likewise, since we are processing a single image (or sample), the returned tensor will always have shape
#
# $$
# (1, 224, 224, 3).
# $$
#
# The `paths_to_tensor` function takes a numpy array of string-valued image paths as input and returns a 4D tensor with shape
#
# $$
# (\text{nb_samples}, 224, 224, 3).
# $$
#
# Here, `nb_samples` is the number of samples, or number of images, in the supplied array of image paths.  It is best to think of `nb_samples` as the number of 3D tensors (where each 3D tensor corresponds to a different image) in your dataset!

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# ### Making Predictions with ResNet-50
#
# Getting the 4D tensor ready for ResNet-50, and for any other pre-trained model in Keras, requires some additional processing.  First, the RGB image is converted to BGR by reordering the channels.  All pre-trained models have the additional normalization step that the mean pixel (expressed in RGB as $[103.939, 116.779, 123.68]$ and calculated from all pixels in all images in ImageNet) must be subtracted from every pixel in each image.  This is implemented in the imported function `preprocess_input`.  If you're curious, you can check the code for `preprocess_input` [here](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py).
#
# Now that we have a way to format our image for supplying to ResNet-50, we are now ready to use the model to extract the predictions.  This is accomplished with the `predict` method, which returns an array whose $i$-th entry is the model's predicted probability that the image belongs to the $i$-th ImageNet category.  This is implemented in the `ResNet50_predict_labels` function below.
#
# By taking the argmax of the predicted probability vector, we obtain an integer corresponding to the model's predicted object class, which we can identify with an object category through the use of this [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
from keras.applications.resnet50 import preprocess_input, decode_predictions

def ResNet50_predict_labels(img_path):
    # returns prediction vector for image located at img_path
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %% [markdown]
# ### Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained ResNet-50 model, we need only check if the `ResNet50_predict_labels` function above returns a value between 151 and 268 (inclusive).
#
# We use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 3:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?
#
# __Answer:__

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.

human_result = []
for x in human_files_short:
    human_result.append(dog_detector(x))
dog_result = []
for x in dog_files_short:
    dog_result.append(dog_detector(x))
    
print(sum(human_result))
print(sum(human_result) == len(human_files_short))
print(sum(dog_result))
print(sum(dog_result) == len(dog_files_short))
# Out:
# 0
# False
# 100
# True

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 1%.  In Step 5 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# Be careful with adding too many trainable layers!  More parameters means longer training, which means you are more likely to need a GPU to accelerate the training process.  Thankfully, Keras provides a handy estimate of the time that each epoch is likely to take; you can extrapolate this estimate to figure out how long it will take for your algorithm to train.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have great difficulty in distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### Pre-process the Data
#
# We rescale the images by dividing every pixel in every image by 255.

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████| 6680/6680 [01:08<00:00, 97.75it/s]
# 100%|██████████| 835/835 [00:07<00:00, 114.57it/s]
# 100%|██████████| 836/836 [00:07<00:00, 112.80it/s]

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         model.summary()
#
# We have imported some Python modules to get you started, but feel free to import as many modules as you need.  If you end up getting stuck, here's a hint that specifies a model that trains relatively fast on CPU and attains >1% test accuracy in 5 epochs:
#
# ![Sample CNN](images/sample_cnn.png)
#
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  If you chose to use the hinted architecture above, describe why you think that CNN architecture should work well for the image classification task.
#
# __Answer:__
# In my opinion and through trial and error, the original network architeture will overfit on the training and validation data. I need to add more layers and experiment with dropout and regularization but that requires strong hardware so I stopped at minimal modifications to the proposed architecture. I increased the number of neurons at each layer with respect to the proposed architecture. And after the feedback on the first submission, I added Batch Normalization layers and a kernel regularizer at the last layer (the dense layer) to boost the learning process and avoid overfitting.

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense, BatchNormalization, Activation
from keras.models import Sequential
from keras import regularizers

model = Sequential()

### TODO: Define your architecture.

model.add(Conv2D(64, (2, 2), input_shape=train_tensors.shape[1:]))
model.add(BatchNormalization())
model.add(Activation("relu"))
#model.add(Dense(int(number_of_neurons), activation='relu',kernel_regularizer=regularizers.l2(0)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, (2, 2)))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(256, (2, 2)))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(512, (2, 2)))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(GlobalAveragePooling2D())
model.add(Dense(133, activation='softmax', kernel_regularizer=regularizers.l2(0.01)))
# Compiling the model using categorical_crossentropy loss, and rmsprop optimizer.

model.summary()
print(train_tensors.shape)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 223, 223, 64)      832
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 223, 223, 64)      256
# _________________________________________________________________
# activation_50 (Activation)   (None, 223, 223, 64)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 111, 111, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 110, 110, 128)     32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 110, 110, 128)     512
# _________________________________________________________________
# activation_51 (Activation)   (None, 110, 110, 128)     0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 55, 55, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 54, 54, 256)       131328
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 54, 54, 256)       1024
# _________________________________________________________________
# activation_52 (Activation)   (None, 54, 54, 256)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 27, 27, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 26, 26, 512)       524800
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 26, 26, 512)       2048
# _________________________________________________________________
# activation_53 (Activation)   (None, 26, 26, 512)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 13, 13, 512)       0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 761,925
# Trainable params: 760,005
# Non-trainable params: 1,920
# _________________________________________________________________
# (6680, 224, 224, 3)

# %% [markdown]
# ### Compile the Model

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 100

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 6.0824 - acc: 0.0245Epoch 00001: val_loss improved from inf to 6.26765, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 115s 17ms/step - loss: 6.0801 - acc: 0.0246 - val_loss: 6.2676 - val_acc: 0.0072
# Epoch 2/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 5.0650 - acc: 0.0368Epoch 00002: val_loss improved from 6.26765 to 5.14083, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 114s 17ms/step - loss: 5.0648 - acc: 0.0367 - val_loss: 5.1408 - val_acc: 0.0275
# Epoch 3/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.7075 - acc: 0.0471Epoch 00003: val_loss improved from 5.14083 to 4.81215, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 114s 17ms/step - loss: 4.7064 - acc: 0.0473 - val_loss: 4.8122 - val_acc: 0.0287
# Epoch 4/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.5376 - acc: 0.0644Epoch 00004: val_loss improved from 4.81215 to 4.73685, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 114s 17ms/step - loss: 4.5375 - acc: 0.0647 - val_loss: 4.7368 - val_acc: 0.0479
# Epoch 5/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.4471 - acc: 0.0728Epoch 00005: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 4.4465 - acc: 0.0732 - val_loss: 5.0391 - val_acc: 0.0275
# Epoch 6/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.3647 - acc: 0.0797Epoch 00006: val_loss improved from 4.73685 to 4.60528, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 113s 17ms/step - loss: 4.3635 - acc: 0.0801 - val_loss: 4.6053 - val_acc: 0.0647
# Epoch 7/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.2898 - acc: 0.0916Epoch 00007: val_loss improved from 4.60528 to 4.40405, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 113s 17ms/step - loss: 4.2896 - acc: 0.0918 - val_loss: 4.4041 - val_acc: 0.0814
# Epoch 8/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.2445 - acc: 0.0959Epoch 00008: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 4.2444 - acc: 0.0960 - val_loss: 4.6412 - val_acc: 0.0743
# Epoch 9/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.1698 - acc: 0.1080Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 4.1697 - acc: 0.1082 - val_loss: 4.6758 - val_acc: 0.0599
# Epoch 10/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.1200 - acc: 0.1177Epoch 00010: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 4.1191 - acc: 0.1177 - val_loss: 6.8825 - val_acc: 0.0371
# Epoch 11/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.0563 - acc: 0.1315Epoch 00011: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 4.0548 - acc: 0.1317 - val_loss: 5.2069 - val_acc: 0.0599
# Epoch 12/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.9797 - acc: 0.1437Epoch 00012: val_loss improved from 4.40405 to 4.32623, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.9803 - acc: 0.1442 - val_loss: 4.3262 - val_acc: 0.0994
# Epoch 13/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.9394 - acc: 0.1477Epoch 00013: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.9388 - acc: 0.1476 - val_loss: 7.3778 - val_acc: 0.0311
# Epoch 14/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.8916 - acc: 0.1626Epoch 00014: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.8919 - acc: 0.1624 - val_loss: 4.7751 - val_acc: 0.0874
# Epoch 15/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.8354 - acc: 0.1698Epoch 00015: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.8366 - acc: 0.1698 - val_loss: 5.4685 - val_acc: 0.0659
# Epoch 16/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.7737 - acc: 0.1823Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.7728 - acc: 0.1828 - val_loss: 6.3290 - val_acc: 0.0419
# Epoch 17/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.7313 - acc: 0.1913Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.7310 - acc: 0.1910 - val_loss: 4.4322 - val_acc: 0.1222
# Epoch 18/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.6872 - acc: 0.1916Epoch 00018: val_loss improved from 4.32623 to 4.24410, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.6860 - acc: 0.1921 - val_loss: 4.2441 - val_acc: 0.1114
# Epoch 19/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.6483 - acc: 0.2044Epoch 00019: val_loss improved from 4.24410 to 4.21292, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.6470 - acc: 0.2043 - val_loss: 4.2129 - val_acc: 0.1341
# Epoch 20/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5829 - acc: 0.2218Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.5829 - acc: 0.2220 - val_loss: 5.4862 - val_acc: 0.1042
# Epoch 21/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5276 - acc: 0.2257Epoch 00021: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.5280 - acc: 0.2257 - val_loss: 4.3818 - val_acc: 0.1234
# Epoch 22/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5085 - acc: 0.2282Epoch 00022: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.5090 - acc: 0.2278 - val_loss: 4.6270 - val_acc: 0.1042
# Epoch 23/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4618 - acc: 0.2333Epoch 00023: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.4630 - acc: 0.2331 - val_loss: 6.5888 - val_acc: 0.0898
# Epoch 24/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4022 - acc: 0.2598Epoch 00024: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.4036 - acc: 0.2593 - val_loss: 4.3797 - val_acc: 0.1114
# Epoch 25/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3834 - acc: 0.2619Epoch 00025: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.3827 - acc: 0.2620 - val_loss: 5.8877 - val_acc: 0.1006
# Epoch 26/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3167 - acc: 0.2763Epoch 00026: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.3194 - acc: 0.2759 - val_loss: 4.3817 - val_acc: 0.1210
# Epoch 27/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2884 - acc: 0.2785Epoch 00027: val_loss improved from 4.21292 to 4.18349, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.2880 - acc: 0.2783 - val_loss: 4.1835 - val_acc: 0.1389
# Epoch 28/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2343 - acc: 0.2907Epoch 00028: val_loss improved from 4.18349 to 3.90490, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.2339 - acc: 0.2909 - val_loss: 3.9049 - val_acc: 0.1856
# Epoch 29/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2137 - acc: 0.3047Epoch 00029: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.2134 - acc: 0.3046 - val_loss: 4.5369 - val_acc: 0.1269
# Epoch 30/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1482 - acc: 0.3090Epoch 00030: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.1498 - acc: 0.3085 - val_loss: 4.9630 - val_acc: 0.1329
# Epoch 31/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1143 - acc: 0.3230Epoch 00031: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.1144 - acc: 0.3231 - val_loss: 4.0355 - val_acc: 0.1976
# Epoch 32/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.0997 - acc: 0.3203Epoch 00032: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.1011 - acc: 0.3201 - val_loss: 4.9817 - val_acc: 0.1138
# Epoch 33/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.0523 - acc: 0.3435Epoch 00033: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.0514 - acc: 0.3433 - val_loss: 3.9337 - val_acc: 0.1737
# Epoch 34/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.0215 - acc: 0.3435Epoch 00034: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 3.0212 - acc: 0.3434 - val_loss: 4.6487 - val_acc: 0.1461
# Epoch 35/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.9866 - acc: 0.3486Epoch 00035: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.9863 - acc: 0.3485 - val_loss: 5.7332 - val_acc: 0.0814
# Epoch 36/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.9520 - acc: 0.3596Epoch 00036: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.9518 - acc: 0.3594 - val_loss: 4.7294 - val_acc: 0.1557
# Epoch 37/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.9177 - acc: 0.3677Epoch 00037: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.9185 - acc: 0.3677 - val_loss: 5.8423 - val_acc: 0.0790
# Epoch 38/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.8641 - acc: 0.3880Epoch 00038: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.8655 - acc: 0.3880 - val_loss: 4.4699 - val_acc: 0.1497
# Epoch 39/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.8619 - acc: 0.3811Epoch 00039: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.8618 - acc: 0.3807 - val_loss: 8.5696 - val_acc: 0.0527
# Epoch 40/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.8002 - acc: 0.4072Epoch 00040: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.8007 - acc: 0.4073 - val_loss: 5.4255 - val_acc: 0.1269
# Epoch 41/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.7740 - acc: 0.4155Epoch 00041: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.7737 - acc: 0.4157 - val_loss: 4.9341 - val_acc: 0.1341
# Epoch 42/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.7315 - acc: 0.4254Epoch 00042: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.7313 - acc: 0.4254 - val_loss: 4.5480 - val_acc: 0.1617
# Epoch 43/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.7032 - acc: 0.4315Epoch 00043: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.7048 - acc: 0.4310 - val_loss: 4.1429 - val_acc: 0.1868
# Epoch 44/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.6912 - acc: 0.4329Epoch 00044: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.6918 - acc: 0.4328 - val_loss: 4.9870 - val_acc: 0.1018
# Epoch 45/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.6524 - acc: 0.4438Epoch 00045: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.6518 - acc: 0.4445 - val_loss: 6.9078 - val_acc: 0.0659
# Epoch 46/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.6087 - acc: 0.4578Epoch 00046: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.6087 - acc: 0.4581 - val_loss: 4.2545 - val_acc: 0.1605
# Epoch 47/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.5764 - acc: 0.4659Epoch 00047: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.5765 - acc: 0.4656 - val_loss: 4.6234 - val_acc: 0.1545
# Epoch 48/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.5287 - acc: 0.4760Epoch 00048: val_loss improved from 3.90490 to 3.63887, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.5271 - acc: 0.4769 - val_loss: 3.6389 - val_acc: 0.2443
# Epoch 49/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.5337 - acc: 0.4730Epoch 00049: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.5335 - acc: 0.4729 - val_loss: 4.9187 - val_acc: 0.1150
# Epoch 50/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.5004 - acc: 0.4755Epoch 00050: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.5001 - acc: 0.4757 - val_loss: 4.1336 - val_acc: 0.1868
# Epoch 51/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.4601 - acc: 0.4998Epoch 00051: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.4613 - acc: 0.4991 - val_loss: 4.6920 - val_acc: 0.1509
# Epoch 52/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.4383 - acc: 0.5005Epoch 00052: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.4400 - acc: 0.4999 - val_loss: 4.0748 - val_acc: 0.2000
# Epoch 53/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.4012 - acc: 0.5149Epoch 00053: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.4016 - acc: 0.5150 - val_loss: 4.8901 - val_acc: 0.1138
# Epoch 54/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.3554 - acc: 0.5279Epoch 00054: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.3573 - acc: 0.5272 - val_loss: 4.7528 - val_acc: 0.1377
# Epoch 55/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.3344 - acc: 0.5351Epoch 00055: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.3338 - acc: 0.5350 - val_loss: 4.7036 - val_acc: 0.1653
# Epoch 56/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.3148 - acc: 0.5353Epoch 00056: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.3148 - acc: 0.5353 - val_loss: 5.2855 - val_acc: 0.1329
# Epoch 57/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.2822 - acc: 0.5502Epoch 00057: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.2840 - acc: 0.5499 - val_loss: 6.8996 - val_acc: 0.1078
# Epoch 58/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.2193 - acc: 0.5701Epoch 00058: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.2196 - acc: 0.5698 - val_loss: 4.5031 - val_acc: 0.2000
# Epoch 59/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.2083 - acc: 0.5847Epoch 00059: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.2095 - acc: 0.5843 - val_loss: 3.9744 - val_acc: 0.2132
# Epoch 60/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.1882 - acc: 0.5772Epoch 00060: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.1903 - acc: 0.5768 - val_loss: 3.7478 - val_acc: 0.2228
# Epoch 61/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.1432 - acc: 0.6008Epoch 00061: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.1446 - acc: 0.6003 - val_loss: 4.8727 - val_acc: 0.1461
# Epoch 62/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.1502 - acc: 0.5923Epoch 00062: val_loss improved from 3.63887 to 3.61093, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.1510 - acc: 0.5918 - val_loss: 3.6109 - val_acc: 0.2719
# Epoch 63/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.1058 - acc: 0.5959Epoch 00063: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.1066 - acc: 0.5955 - val_loss: 4.1549 - val_acc: 0.1916
# Epoch 64/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.0403 - acc: 0.6267Epoch 00064: val_loss improved from 3.61093 to 3.50710, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.0418 - acc: 0.6259 - val_loss: 3.5071 - val_acc: 0.2802
# Epoch 65/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.0360 - acc: 0.6218Epoch 00065: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.0361 - acc: 0.6216 - val_loss: 4.8940 - val_acc: 0.1808
# Epoch 66/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.0178 - acc: 0.6344Epoch 00066: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 2.0168 - acc: 0.6346 - val_loss: 4.3211 - val_acc: 0.2395
# Epoch 67/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.9894 - acc: 0.6416Epoch 00067: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.9896 - acc: 0.6416 - val_loss: 4.0421 - val_acc: 0.1808
# Epoch 68/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.9795 - acc: 0.6461Epoch 00068: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.9805 - acc: 0.6458 - val_loss: 4.8421 - val_acc: 0.1629
# Epoch 69/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.9216 - acc: 0.6599Epoch 00069: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.9215 - acc: 0.6597 - val_loss: 4.3356 - val_acc: 0.1844
# Epoch 70/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.9293 - acc: 0.6556Epoch 00070: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.9274 - acc: 0.6564 - val_loss: 6.5984 - val_acc: 0.1269
# Epoch 71/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.8561 - acc: 0.6850Epoch 00071: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.8564 - acc: 0.6849 - val_loss: 5.3662 - val_acc: 0.1617
# Epoch 72/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.8623 - acc: 0.6791Epoch 00072: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.8619 - acc: 0.6792 - val_loss: 4.2108 - val_acc: 0.2120
# Epoch 73/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.8010 - acc: 0.6902Epoch 00073: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.8005 - acc: 0.6906 - val_loss: 3.9573 - val_acc: 0.2707
# Epoch 74/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.7894 - acc: 0.6962Epoch 00074: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.7894 - acc: 0.6961 - val_loss: 4.2135 - val_acc: 0.2263
# Epoch 75/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.7892 - acc: 0.6947Epoch 00075: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.7896 - acc: 0.6948 - val_loss: 3.8449 - val_acc: 0.2695
# Epoch 76/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.7526 - acc: 0.7090Epoch 00076: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.7529 - acc: 0.7091 - val_loss: 4.5566 - val_acc: 0.2263
# Epoch 77/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.7207 - acc: 0.7200Epoch 00077: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.7207 - acc: 0.7199 - val_loss: 4.9491 - val_acc: 0.1581
# Epoch 78/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.6959 - acc: 0.7261Epoch 00078: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.6974 - acc: 0.7259 - val_loss: 5.1825 - val_acc: 0.1677
# Epoch 79/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.6823 - acc: 0.7357Epoch 00079: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.6815 - acc: 0.7361 - val_loss: 5.5317 - val_acc: 0.1473
# Epoch 80/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.6678 - acc: 0.7320Epoch 00080: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.6680 - acc: 0.7317 - val_loss: 4.6017 - val_acc: 0.2060
# Epoch 81/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.6294 - acc: 0.7464Epoch 00081: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.6309 - acc: 0.7461 - val_loss: 4.5635 - val_acc: 0.1820
# Epoch 82/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.5967 - acc: 0.7610Epoch 00082: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.5963 - acc: 0.7614 - val_loss: 4.7073 - val_acc: 0.1808
# Epoch 83/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.5813 - acc: 0.7619Epoch 00083: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.5811 - acc: 0.7618 - val_loss: 4.6250 - val_acc: 0.1856
# Epoch 84/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.5608 - acc: 0.7674Epoch 00084: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.5618 - acc: 0.7668 - val_loss: 4.6634 - val_acc: 0.2012
# Epoch 85/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.5581 - acc: 0.7608Epoch 00085: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.5584 - acc: 0.7606 - val_loss: 4.6566 - val_acc: 0.1749
# Epoch 86/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.5128 - acc: 0.7832Epoch 00086: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.5141 - acc: 0.7832 - val_loss: 4.3835 - val_acc: 0.2192
# Epoch 87/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.4723 - acc: 0.7980Epoch 00087: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.4719 - acc: 0.7984 - val_loss: 5.4793 - val_acc: 0.1461
# Epoch 88/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.4898 - acc: 0.7823Epoch 00088: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.4914 - acc: 0.7816 - val_loss: 4.1829 - val_acc: 0.2240
# Epoch 89/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.4489 - acc: 0.7947Epoch 00089: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.4500 - acc: 0.7946 - val_loss: 4.9169 - val_acc: 0.1677
# Epoch 90/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.4315 - acc: 0.8026Epoch 00090: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.4313 - acc: 0.8027 - val_loss: 5.6359 - val_acc: 0.1102
# Epoch 91/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.3941 - acc: 0.8140Epoch 00091: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.3946 - acc: 0.8139 - val_loss: 5.3244 - val_acc: 0.1928
# Epoch 92/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.4177 - acc: 0.8083Epoch 00092: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.4190 - acc: 0.8079 - val_loss: 7.0903 - val_acc: 0.1198
# Epoch 93/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.3726 - acc: 0.8216Epoch 00093: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.3731 - acc: 0.8213 - val_loss: 4.3943 - val_acc: 0.2096
# Epoch 94/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.3880 - acc: 0.8152Epoch 00094: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.3884 - acc: 0.8150 - val_loss: 4.6997 - val_acc: 0.1665
# Epoch 95/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.3374 - acc: 0.8293Epoch 00095: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.3386 - acc: 0.8290 - val_loss: 5.0591 - val_acc: 0.1641
# Epoch 96/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.3077 - acc: 0.8342Epoch 00096: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.3068 - acc: 0.8346 - val_loss: 4.3107 - val_acc: 0.2036
# Epoch 97/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.3135 - acc: 0.8282Epoch 00097: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.3134 - acc: 0.8283 - val_loss: 4.2861 - val_acc: 0.2263
# Epoch 98/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.3040 - acc: 0.8392Epoch 00098: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.3050 - acc: 0.8386 - val_loss: 4.5379 - val_acc: 0.1988
# Epoch 99/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.2828 - acc: 0.8371Epoch 00099: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.2827 - acc: 0.8373 - val_loss: 5.0274 - val_acc: 0.1820
# Epoch 100/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.2575 - acc: 0.8459Epoch 00100: val_loss did not improve
# 6680/6680 [==============================] - 113s 17ms/step - loss: 1.2577 - acc: 0.8460 - val_loss: 4.1134 - val_acc: 0.2287

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
model.load_weights('saved_models/weights.best.from_scratch.hdf5')

# %% [markdown]
# ### Test the Model
#
# Try out your model on the test dataset of dog images.  Ensure that your test accuracy is greater than 1%.

# %%
# get index of predicted dog breed for each image in test set
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(test_targets, axis=1))/len(dog_breed_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 27.5120%

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Use a CNN to Classify Dog Breeds
#
# To reduce training time without sacrificing accuracy, we show you how to train a CNN using transfer learning.  In the following step, you will get a chance to use transfer learning to train your own CNN.
#
# ### Obtain Bottleneck Features

# %%
bottleneck_features = np.load('/data/bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features['train']
valid_VGG16 = bottleneck_features['valid']
test_VGG16 = bottleneck_features['test']

# %% [markdown]
# ### Model Architecture
#
# The model uses the the pre-trained VGG-16 model as a fixed feature extractor, where the last convolutional output of VGG-16 is fed as input to our model.  We only add a global average pooling layer and a fully connected layer, where the latter contains one node for each dog category and is equipped with a softmax.

# %%
VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:]))
VGG16_model.add(Dense(133, activation='softmax'))

VGG16_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_2 ( (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229
# Trainable params: 68,229
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### Train the Model

# %%
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG16.hdf5', 
                               verbose=1, save_best_only=True)

VGG16_model.fit(train_VGG16, train_targets, 
          validation_data=(valid_VGG16, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 12.8563 - acc: 0.1033Epoch 00001: val_loss improved from inf to 11.38221, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 312us/step - loss: 12.8392 - acc: 0.1039 - val_loss: 11.3822 - val_acc: 0.1928
# Epoch 2/20
# 6500/6680 [============================>.] - ETA: 0s - loss: 10.9133 - acc: 0.2394Epoch 00002: val_loss improved from 11.38221 to 10.95816, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 248us/step - loss: 10.9143 - acc: 0.2398 - val_loss: 10.9582 - val_acc: 0.2575
# Epoch 3/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 10.4668 - acc: 0.2921Epoch 00003: val_loss improved from 10.95816 to 10.69004, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 246us/step - loss: 10.4746 - acc: 0.2921 - val_loss: 10.6900 - val_acc: 0.2659
# Epoch 4/20
# 6480/6680 [============================>.] - ETA: 0s - loss: 10.1883 - acc: 0.3204Epoch 00004: val_loss improved from 10.69004 to 10.55491, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 247us/step - loss: 10.1855 - acc: 0.3202 - val_loss: 10.5549 - val_acc: 0.2850
# Epoch 5/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 9.9765 - acc: 0.3474Epoch 00005: val_loss improved from 10.55491 to 10.35598, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 246us/step - loss: 9.9759 - acc: 0.3473 - val_loss: 10.3560 - val_acc: 0.3066
# Epoch 6/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 9.7980 - acc: 0.3666Epoch 00006: val_loss improved from 10.35598 to 10.27561, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 246us/step - loss: 9.7928 - acc: 0.3671 - val_loss: 10.2756 - val_acc: 0.3018
# Epoch 7/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 9.5973 - acc: 0.3769Epoch 00007: val_loss improved from 10.27561 to 10.03543, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 245us/step - loss: 9.6048 - acc: 0.3765 - val_loss: 10.0354 - val_acc: 0.3246
# Epoch 8/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 9.3884 - acc: 0.3955Epoch 00008: val_loss improved from 10.03543 to 9.84921, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 246us/step - loss: 9.3961 - acc: 0.3948 - val_loss: 9.8492 - val_acc: 0.3293
# Epoch 9/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 9.1153 - acc: 0.4084Epoch 00009: val_loss improved from 9.84921 to 9.62582, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 246us/step - loss: 9.1118 - acc: 0.4087 - val_loss: 9.6258 - val_acc: 0.3329
# Epoch 10/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 8.9690 - acc: 0.4253Epoch 00010: val_loss improved from 9.62582 to 9.53635, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 247us/step - loss: 8.9735 - acc: 0.4246 - val_loss: 9.5363 - val_acc: 0.3557
# Epoch 11/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 8.8220 - acc: 0.4329Epoch 00011: val_loss improved from 9.53635 to 9.41919, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 246us/step - loss: 8.8249 - acc: 0.4329 - val_loss: 9.4192 - val_acc: 0.3521
# Epoch 12/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 8.6887 - acc: 0.4430Epoch 00012: val_loss improved from 9.41919 to 9.37543, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 246us/step - loss: 8.6833 - acc: 0.4434 - val_loss: 9.3754 - val_acc: 0.3593
# Epoch 13/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 8.6284 - acc: 0.4509Epoch 00013: val_loss improved from 9.37543 to 9.30835, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 245us/step - loss: 8.6332 - acc: 0.4503 - val_loss: 9.3084 - val_acc: 0.3653
# Epoch 14/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 8.4842 - acc: 0.4576Epoch 00014: val_loss improved from 9.30835 to 9.20581, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 245us/step - loss: 8.4652 - acc: 0.4585 - val_loss: 9.2058 - val_acc: 0.3713
# Epoch 15/20
# 6460/6680 [============================>.] - ETA: 0s - loss: 8.3523 - acc: 0.4715Epoch 00015: val_loss improved from 9.20581 to 9.07396, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 245us/step - loss: 8.3674 - acc: 0.4708 - val_loss: 9.0740 - val_acc: 0.3808
# Epoch 16/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 8.3612 - acc: 0.4750Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 2s 244us/step - loss: 8.3483 - acc: 0.4756 - val_loss: 9.1555 - val_acc: 0.3749
# Epoch 17/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 8.3202 - acc: 0.4796Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 2s 245us/step - loss: 8.3324 - acc: 0.4789 - val_loss: 9.1711 - val_acc: 0.3784
# Epoch 18/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 8.3254 - acc: 0.4799Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 2s 245us/step - loss: 8.3312 - acc: 0.4796 - val_loss: 9.1135 - val_acc: 0.3832
# Epoch 19/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 8.3012 - acc: 0.4798Epoch 00019: val_loss improved from 9.07396 to 9.04094, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 245us/step - loss: 8.3022 - acc: 0.4798 - val_loss: 9.0409 - val_acc: 0.3868
# Epoch 20/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 8.2325 - acc: 0.4841Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 2s 244us/step - loss: 8.2272 - acc: 0.4844 - val_loss: 9.0714 - val_acc: 0.3820

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
VGG16_model.load_weights('saved_models/weights.best.VGG16.hdf5')

# %% [markdown]
# ### Test the Model
#
# Now, we can use the CNN to test how well it identifies breed within our test dataset of dog images.  We print the test accuracy below.

# %%
# get index of predicted dog breed for each image in test set
VGG16_predictions = [np.argmax(VGG16_model.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 37.9187%

# %% [markdown]
# ### Predict Dog Breed with the Model

# %%
from extract_bottleneck_features import *

def VGG16_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# In Step 4, we used transfer learning to create a CNN using VGG-16 bottleneck features.  In this section, you must use the bottleneck features from a different pre-trained model.  To make things easier for you, we have pre-computed the features for all of the networks that are currently available in Keras.  These are already in the workspace, at /data/bottleneck_features.  If you wish to download them on a different machine, they can be found at:
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# The files are encoded as such:
#
#     Dog{network}Data.npz
#
# where `{network}`, in the above filename, can be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.
#
# The above architectures are downloaded and stored for you in the `/data/bottleneck_features/` folder.
#
# This means the following will be in the `/data/bottleneck_features/` folder:
#
# `DogVGG19Data.npz`
# `DogResnet50Data.npz`
# `DogInceptionV3Data.npz`
# `DogXceptionData.npz`
#
#
#
# ### (IMPLEMENTATION) Obtain Bottleneck Features
#
# In the code block below, extract the bottleneck features corresponding to the train, test, and validation sets by running the following:
#
#     bottleneck_features = np.load('/data/bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %%
### TODO: Obtain bottleneck features from another pre-trained CNN.
bottleneck_features = np.load('/data/bottleneck_features/DogResnet50Data.npz')
train_Resnet50 = bottleneck_features['train']
valid_Resnet50 = bottleneck_features['valid']
test_Resnet50 = bottleneck_features['test']

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         <your model's name>.summary()
#
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.
#
# __Answer:__
# I experimented with the addition and removal of a convolutional layer. Since I found that the accuracy in the training phase was really high in the case of adding additional global pooling and dense layers only, I settled on using the minimal number of layers possible.

# %%
### TODO: Define your architecture.
Resnet50_model = Sequential()
#VGG19_model.add(Conv2D(512, (2, 2), activation='relu', input_shape=train_VGG19.shape[1:]))
Resnet50_model.add(GlobalAveragePooling2D(input_shape=train_Resnet50.shape[1:]))
Resnet50_model.add(Dense(133, activation='softmax'))

Resnet50_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_3 ( (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 133)               272517
# =================================================================
# Total params: 272,517
# Trainable params: 272,517
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### (IMPLEMENTATION) Compile the Model

# %%
### TODO: Compile the model.
Resnet50_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
### TODO: Train the model.
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.Resnet50.hdf5', 
                               verbose=1, save_best_only=True)

Resnet50_model.fit(train_Resnet50, train_targets, 
          validation_data=(valid_Resnet50, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 1.6460 - acc: 0.5914Epoch 00001: val_loss improved from inf to 0.82223, saving model to saved_models/weights.best.Resnet50.hdf5
# 6680/6680 [==============================] - 2s 272us/step - loss: 1.6243 - acc: 0.5966 - val_loss: 0.8222 - val_acc: 0.7365
# Epoch 2/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.4477 - acc: 0.8606Epoch 00002: val_loss improved from 0.82223 to 0.68489, saving model to saved_models/weights.best.Resnet50.hdf5
# 6680/6680 [==============================] - 1s 216us/step - loss: 0.4453 - acc: 0.8611 - val_loss: 0.6849 - val_acc: 0.7808
# Epoch 3/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.2655 - acc: 0.9117Epoch 00003: val_loss improved from 0.68489 to 0.64854, saving model to saved_models/weights.best.Resnet50.hdf5
# 6680/6680 [==============================] - 1s 216us/step - loss: 0.2656 - acc: 0.9114 - val_loss: 0.6485 - val_acc: 0.8036
# Epoch 4/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.1816 - acc: 0.9466Epoch 00004: val_loss did not improve
# 6680/6680 [==============================] - 1s 213us/step - loss: 0.1809 - acc: 0.9466 - val_loss: 0.7030 - val_acc: 0.7976
# Epoch 5/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.1213 - acc: 0.9623Epoch 00005: val_loss improved from 0.64854 to 0.63113, saving model to saved_models/weights.best.Resnet50.hdf5
# 6680/6680 [==============================] - 1s 214us/step - loss: 0.1231 - acc: 0.9615 - val_loss: 0.6311 - val_acc: 0.8180
# Epoch 6/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0869 - acc: 0.9742Epoch 00006: val_loss did not improve
# 6680/6680 [==============================] - 1s 213us/step - loss: 0.0877 - acc: 0.9740 - val_loss: 0.7002 - val_acc: 0.8096
# Epoch 7/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0642 - acc: 0.9833Epoch 00007: val_loss did not improve
# 6680/6680 [==============================] - 1s 213us/step - loss: 0.0657 - acc: 0.9828 - val_loss: 0.6744 - val_acc: 0.8144
# Epoch 8/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0501 - acc: 0.9863Epoch 00008: val_loss did not improve
# 6680/6680 [==============================] - 1s 213us/step - loss: 0.0504 - acc: 0.9862 - val_loss: 0.6587 - val_acc: 0.8347
# Epoch 9/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0360 - acc: 0.9911Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 1s 215us/step - loss: 0.0360 - acc: 0.9910 - val_loss: 0.7348 - val_acc: 0.8216
# Epoch 10/20
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0284 - acc: 0.9928Epoch 00010: val_loss did not improve
# 6680/6680 [==============================] - 1s 215us/step - loss: 0.0289 - acc: 0.9927 - val_loss: 0.7465 - val_acc: 0.8192
# Epoch 11/20
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0229 - acc: 0.9951Epoch 00011: val_loss did not improve
# 6680/6680 [==============================] - 1s 214us/step - loss: 0.0228 - acc: 0.9951 - val_loss: 0.7836 - val_acc: 0.8156
# Epoch 12/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0194 - acc: 0.9957Epoch 00012: val_loss did not improve
# 6680/6680 [==============================] - 1s 213us/step - loss: 0.0194 - acc: 0.9957 - val_loss: 0.7991 - val_acc: 0.8275
# Epoch 13/20
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0162 - acc: 0.9963Epoch 00013: val_loss did not improve
# 6680/6680 [==============================] - 1s 214us/step - loss: 0.0161 - acc: 0.9963 - val_loss: 0.7943 - val_acc: 0.8168
# Epoch 14/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0138 - acc: 0.9966Epoch 00014: val_loss did not improve
# 6680/6680 [==============================] - 1s 215us/step - loss: 0.0137 - acc: 0.9967 - val_loss: 0.7623 - val_acc: 0.8287
# Epoch 15/20
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0116 - acc: 0.9974Epoch 00015: val_loss did not improve
# 6680/6680 [==============================] - 1s 215us/step - loss: 0.0113 - acc: 0.9975 - val_loss: 0.8326 - val_acc: 0.8216
# Epoch 16/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0105 - acc: 0.9968Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 1s 215us/step - loss: 0.0103 - acc: 0.9969 - val_loss: 0.8922 - val_acc: 0.8263
# Epoch 17/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0084 - acc: 0.9980Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 1s 213us/step - loss: 0.0083 - acc: 0.9981 - val_loss: 0.8584 - val_acc: 0.8228
# Epoch 18/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0062 - acc: 0.9988Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 1s 214us/step - loss: 0.0071 - acc: 0.9987 - val_loss: 0.9064 - val_acc: 0.8228
# Epoch 19/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0076 - acc: 0.9979Epoch 00019: val_loss did not improve
# 6680/6680 [==============================] - 1s 214us/step - loss: 0.0074 - acc: 0.9979 - val_loss: 0.9024 - val_acc: 0.8263
# Epoch 20/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0064 - acc: 0.9983Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 1s 214us/step - loss: 0.0063 - acc: 0.9984 - val_loss: 0.9463 - val_acc: 0.8240

# %% [markdown]
# ### (IMPLEMENTATION) Load the Model with the Best Validation Loss

# %%
### TODO: Load the model weights with the best validation loss.
Resnet50_model.load_weights('saved_models/weights.best.Resnet50.hdf5')

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Ensure that your test accuracy is greater than 60%.

# %%
### TODO: Calculate classification accuracy on the test dataset.
Resnet50_predictions = [np.argmax(Resnet50_model.predict(np.expand_dims(feature, axis=0))) for feature in test_Resnet50]

# report test accuracy
test_accuracy = 100*np.sum(np.array(Resnet50_predictions)==np.argmax(test_targets, axis=1))/len(Resnet50_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 80.5024%

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan_hound`, etc) that is predicted by your model.
#
# Similar to the analogous function in Step 5, your function should have three steps:
# 1. Extract the bottleneck features corresponding to the chosen CNN model.
# 2. Supply the bottleneck features as input to the model to return the predicted vector.  Note that the argmax of this prediction vector gives the index of the predicted dog breed.
# 3. Use the `dog_names` array defined in Step 0 of this notebook to return the corresponding breed.
#
# The functions to extract the bottleneck features can be found in `extract_bottleneck_features.py`, and they have been imported in an earlier code cell.  To obtain the bottleneck features corresponding to your chosen CNN architecture, you need to use the function
#
#     extract_{network}
#
# where `{network}`, in the above filename, should be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.

def dog_detector_custom(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_Resnet50(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = Resnet50_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)].split(".")[1]

print(dog_detector_custom(human_files_short[5]))
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94658560/94653016 [==============================] - 2s 0us/step
# Beagle

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 5 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.
def algo(img_path):
    if (dog_detector(img_path)):
        print("The dog looks like " + dog_detector_custom(img_path))
    elif (face_detector(img_path)):
        print ("The human looks like " + dog_detector_custom(img_path))
    else:
        print("Nothing was detected")

# %% [markdown]
# ---
# <a id='step7'></a>
# ## Step 7: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that __you__ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.
#
# __Answer:__
# The output is better than I expected. For future work:
# 1. I would like to add a dog face detector using opencv to box the face of the detected dog
# 2. Add the possibility of detecting human beings and dogs in one picture
# 3. Add the possibility of using the old and new capibilities of the cnn on which transfer learning was applied (Since it was trained to detect objects other than dogs too)

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.
#algo(test_Resnet50[100])
#algo(test_Resnet50[100])
#print(dog_detector(dog_names_short[89]))
# extract pre-trained face detector
#face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')
import os 
test_files = []


for dirname, dirnames, filenames in os.walk('images/section_7'):
    for filename in filenames:
        test_files.append(os.path.join(dirname, filename))
        
print(test_files)

for x in test_files:
    algo(x)
    img = cv2.imread(x)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    print('Number of faces detected:', len(faces))
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(cv_rgb)
    plt.show()
# Out:
# ['images/section_7/landscape-gettyimages-530330473-1.jpg', 'images/section_7/george-bush-3_2536602b.jpg', 'images/section_7/AMC_HUM_S1_Promo_Anita.jpg', 'images/section_7/Sarkozy.jpg', 'images/section_7/former-french-president-nicolas-sarkozy-file-photo.jpg', 'images/section_7/German-Shepherd-Background-Wallpaper.jpg', 'images/section_7/inanimate1.jpg', 'images/section_7/Lava_the_sled_dog.jpg', 'images/section_7/9ccce7-20081105-george-bush.jpg', 'images/section_7/DOG-ssssss-dogs-25606625-1024-768.jpg', 'images/section_7/a24c1ff9f784968419784e16f9abdf39.jpg', 'images/section_7/inanimate2.jpg']
# The dog looks like Labrador_retriever
# Number of faces detected: 0
# The human looks like Silky_terrier
# Number of faces detected: 1
# The human looks like Silky_terrier
# Number of faces detected: 1
# The human looks like Silky_terrier
# Number of faces detected: 1
# The human looks like Boston_terrier
# Number of faces detected: 1
# The dog looks like German_shepherd_dog
# Number of faces detected: 0
# Nothing was detected
# Number of faces detected: 0
# The dog looks like Alaskan_malamute
# Number of faces detected: 0
# The human looks like Manchester_terrier
# Number of faces detected: 1
# The dog looks like Golden_retriever
# Number of faces detected: 0
# The dog looks like Labrador_retriever
# Number of faces detected: 0
# Nothing was detected
# Number of faces detected: 0

# %% [markdown]
# # Please download your notebook to submit
